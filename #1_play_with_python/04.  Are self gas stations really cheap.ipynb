# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('../driver/chromedriver')
driver.get('https://www.google.com/webhp?hl=ko&sa=X&ved=0ahUKEwiYi-yV5JzpAhUCat4KHcf8DgkQPAgH')

# %%
driver.save_screenshot('../images/001.jpg')
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:1031: UserWarning: name used for saved screenshot does not match file type. It should end with a `.png` extension
#   "type. It should end with a `.png` extension", UserWarning)
# True

# %%
xpath ="""//*[@id="gb"]/div/div[2]/a"""
driver.find_element_by_xpath(xpath).click()

# %%
elem_login = driver.find_element_by_id("identifierId")
elem_login.clear()
elem_login.send_keys("jeongho2712@gmail.com")

# %%
xpath ="""//*[@id="identifierNext"]/div/button/div[2]"""
driver.find_element_by_xpath(xpath).click()

# %%
driver.close()

# %%
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

driver = webdriver.Chrome('../driver/chromedriver')

driver.get('https://www.opinet.co.kr/searRgSelect.do')

# %%
# xpath ="""//*[@id="header"]/div/ul/li[1]/ul/li[1]/a"""
# driver.find_element_by_xpath(xpath).click()
wait = WebDriverWait(driver, 10)


xpath = wait.until(EC.visibility_of_element_located((By.XPATH, """//*[@id="header"]/div/ul/li[1]/a""")))
ActionChains(driver).move_to_element(xpath).perform()

# benefits = wait.until(EC.visibility_of_element_located((By.XPATH, "//li[@class='item']/a[span='Benefits']")))
# ActionChains(driver).move_to_element(benefits).click().perform()

# %%
xpath ="""//*[@id="header"]/div/ul/li[1]/ul/li[1]/a"""
driver.find_element_by_xpath(xpath).click()

# %%
gu_list_raw = driver.find_element_by_xpath("""//*[@id="SIGUNGU_NM0"]""")
gu_list = gu_list_raw.find_elements_by_tag_name("option")

# %%
gu_names = [option.get_attribute("value") for option in gu_list]
gu_names.remove('')
gu_names
# Out:
# ['계룡시',
#  '공주시',
#  '금산군',
#  '논산시',
#  '당진시',
#  '보령시',
#  '부여군',
#  '서산시',
#  '서천군',
#  '아산시',
#  '예산군',
#  '천안시',
#  '천안시동남구',
#  '천안시서북구',
#  '청양군',
#  '태안군',
#  '홍성군']

# %%
element = driver.find_element_by_id("SIGUNGU_NM0")
element.send_keys(gu_names[13])

# %%
xpath ="""//*[@id="searRgSelect"]/span"""
element_sel_gu = driver.find_element_by_xpath(xpath).click()

# %%
xpath ="""//*[@id="glopopd_excel"]/span"""
element_get_excel = driver.find_element_by_xpath(xpath).click()

# %%
import time
from tqdm import tqdm_notebook


for gu in tqdm_notebook(gu_names):
    element = driver.find_element_by_id("SIGUNGU_NM0")
    element.send_keys(gu)
    
    time.sleep(2)
    
    xpath ="""//*[@id="searRgSelect"]/span"""
    element_sel_gu = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(1)
    
    xpath ="""//*[@id="glopopd_excel"]/span"""
    element_get_excel = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(1)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# HBox(children=(FloatProgress(value=0.0, max=17.0), HTML(value='')))

# %%
driver.close()

# %%
import pandas as pd
from glob import glob

# %%
glob('../data/지역*.xls')
# Out:
# ['../data\\지역_위치별(주유소) (1).xls',
#  '../data\\지역_위치별(주유소) (10).xls',
#  '../data\\지역_위치별(주유소) (11).xls',
#  '../data\\지역_위치별(주유소) (12).xls',
#  '../data\\지역_위치별(주유소) (13).xls',
#  '../data\\지역_위치별(주유소) (14).xls',
#  '../data\\지역_위치별(주유소) (15).xls',
#  '../data\\지역_위치별(주유소) (16).xls',
#  '../data\\지역_위치별(주유소) (17).xls',
#  '../data\\지역_위치별(주유소) (2).xls',
#  '../data\\지역_위치별(주유소) (3).xls',
#  '../data\\지역_위치별(주유소) (4).xls',
#  '../data\\지역_위치별(주유소) (5).xls',
#  '../data\\지역_위치별(주유소) (6).xls',
#  '../data\\지역_위치별(주유소) (7).xls',
#  '../data\\지역_위치별(주유소) (8).xls',
#  '../data\\지역_위치별(주유소) (9).xls',
#  '../data\\지역_위치별(주유소).xls']

# %%
stations_files = glob('../data/지역*.xls')
stations_files
# Out:
# ['../data\\지역_위치별(주유소) (1).xls',
#  '../data\\지역_위치별(주유소) (10).xls',
#  '../data\\지역_위치별(주유소) (11).xls',
#  '../data\\지역_위치별(주유소) (12).xls',
#  '../data\\지역_위치별(주유소) (13).xls',
#  '../data\\지역_위치별(주유소) (14).xls',
#  '../data\\지역_위치별(주유소) (15).xls',
#  '../data\\지역_위치별(주유소) (16).xls',
#  '../data\\지역_위치별(주유소) (17).xls',
#  '../data\\지역_위치별(주유소) (2).xls',
#  '../data\\지역_위치별(주유소) (3).xls',
#  '../data\\지역_위치별(주유소) (4).xls',
#  '../data\\지역_위치별(주유소) (5).xls',
#  '../data\\지역_위치별(주유소) (6).xls',
#  '../data\\지역_위치별(주유소) (7).xls',
#  '../data\\지역_위치별(주유소) (8).xls',
#  '../data\\지역_위치별(주유소) (9).xls',
#  '../data\\지역_위치별(주유소).xls']

# %%
tmp_raw = []


for file_name in stations_files:
    tmp = pd.read_excel(file_name, header=2)
    tmp_raw.append(tmp)
    
stations_raw = pd.concat(tmp_raw)

# %%
stations_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 80
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      1302 non-null   object
#  1   상호      1302 non-null   object
#  2   주소      1302 non-null   object
#  3   상표      1302 non-null   object
#  4   전화번호    1302 non-null   object
#  5   셀프여부    1302 non-null   object
#  6   고급휘발유   1302 non-null   object
#  7   휘발유     1302 non-null   object
#  8   경유      1302 non-null   object
#  9   실내등유    1302 non-null   object
# dtypes: object(10)
# memory usage: 111.9+ KB

# %%
stations_raw
# Out:
#       지역           상호                       주소      상표           전화번호 셀프여부  \
# 0   충청남도      대운셀프주유소     충남 계룡시 신도안면 계룡대로 663   SK에너지   042-551-3289    Y
# 1   충청남도     우체국물류주유소       충남 계룡시 두마면 왕대로 102   알뜰주유소  070-7202-1376    Y
# 2   충청남도        양정주유소      충남 계룡시 엄사면 계백로 3107   S-OIL   042-841-5148    Y
# 3   충청남도        두마주유소    충청남도 계룡시 엄사면 계백로 3025   SK에너지   042-841-1313    N
# 4   충청남도     참좋은셀프주유소      충남 계룡시 엄사면 계룡대로 449   S-OIL   042-841-6699    Y
# ..   ...          ...                      ...     ...            ...  ...
# 76  충청남도    구도일아시아주유소      충남 천안시 서북구 서부대로 421   S-OIL   041-577-1868    N
# 77  충청남도        창성주유소  충남 천안시 서북구 성환읍 성환1로 201   SK에너지   041-581-5151    N
# 78  충청남도    태양주유소/충전소       충남 천안시 서북구 번영로 613   GS칼텍스   041-621-5185    N
# 79  충청남도       신직산주유소    충남 천안시 서북구 직산읍 송기길 90   GS칼텍스   041-583-2031    N
# 80  충청남도  성환농협남부지점주유소   충남 천안시 서북구 성환읍 성환중앙로 8  NH-OIL   041-581-0212    N
#
#    고급휘발유   휘발유    경유 실내등유
# 0      -  1415  1215    -
# 1      -  1439  1239    -
# 2      -  1439  1239    -
# 3      -  1449  1259  840
# 4      -  1489  1289  850
# ..   ...   ...   ...  ...
# 76     -  1538  1298    -
# 77     -  1589  1389  970
# 78     -  1598  1398    -
# 79     -     -     -    -
# 80     -     -     -    -
#
# [1302 rows x 10 columns]

# %%
stations = pd.DataFrame({'Oil_store':stations_raw['상호'],
                        '주소':stations_raw['주소'],
                        '가격':stations_raw['휘발유'],
                        '셀프':stations_raw['셀프여부'],
                        '상표':stations_raw['상표']})

stations
# Out:
#       Oil_store                       주소    가격 셀프      상표
# 0       대운셀프주유소     충남 계룡시 신도안면 계룡대로 663  1415  Y   SK에너지
# 1      우체국물류주유소       충남 계룡시 두마면 왕대로 102  1439  Y   알뜰주유소
# 2         양정주유소      충남 계룡시 엄사면 계백로 3107  1439  Y   S-OIL
# 3         두마주유소    충청남도 계룡시 엄사면 계백로 3025  1449  N   SK에너지
# 4      참좋은셀프주유소      충남 계룡시 엄사면 계룡대로 449  1489  Y   S-OIL
# ..          ...                      ...   ... ..     ...
# 76    구도일아시아주유소      충남 천안시 서북구 서부대로 421  1538  N   S-OIL
# 77        창성주유소  충남 천안시 서북구 성환읍 성환1로 201  1589  N   SK에너지
# 78    태양주유소/충전소       충남 천안시 서북구 번영로 613  1598  N   GS칼텍스
# 79       신직산주유소    충남 천안시 서북구 직산읍 송기길 90     -  N   GS칼텍스
# 80  성환농협남부지점주유소   충남 천안시 서북구 성환읍 성환중앙로 8     -  N  NH-OIL
#
# [1302 rows x 5 columns]

# %%
tmp_station = []

for eachAddress in stations['주소']:
    if eachAddress.split()[1][:2] != "천안":
        tmp_station.append(eachAddress.split()[1][:-1])
    else:
        if eachAddress.split()[2] == "서북구":
            tmp_station.append("천안 서북")
        else:
            tmp_station.append("천안 동남")
#         tmp_station.append(eachAddress.split()[1]+' '+eachAddress.split()[2])
#     [eachAddress.split()[1][:-1] for eachAddress in stations['주소']]

# print(tmp_station)
stations['시군구'] = tmp_station
stations.tail(10)
# Out:
#             Oil_store                         주소    가격 셀프      상표    시군구
# 71          삼성테크노2주유소   충남 천안시 서북구 직산읍 천안대로 1712  1498  N  현대오일뱅크  천안 서북
# 72  현대오일뱅크(주)직영 번영주유소  충남 천안시 서북구 2공단1로 10 (성성동)  1498  N  현대오일뱅크  천안 서북
# 73      SK에너지㈜ 훼미리주유소         충남 천안시 서북구 망향로 244  1498  N   SK에너지  천안 서북
# 74              대성주유소   충남 천안시 서북구 성환읍 천안대로 2021  1498  N   GS칼텍스  천안 서북
# 75              명성주유소     충남 천안시 서북구 직산읍 상덕로 174  1518  N   GS칼텍스  천안 서북
# 76          구도일아시아주유소        충남 천안시 서북구 서부대로 421  1538  N   S-OIL  천안 서북
# 77              창성주유소    충남 천안시 서북구 성환읍 성환1로 201  1589  N   SK에너지  천안 서북
# 78          태양주유소/충전소         충남 천안시 서북구 번영로 613  1598  N   GS칼텍스  천안 서북
# 79             신직산주유소      충남 천안시 서북구 직산읍 송기길 90     -  N   GS칼텍스  천안 서북
# 80        성환농협남부지점주유소     충남 천안시 서북구 성환읍 성환중앙로 8     -  N  NH-OIL  천안 서북

# %%
stations = stations.drop("시", axis=1)

stations.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-1d1aee267abf> in <module>
# ----> 1 stations = stations.drop("시", axis=1)
#       2
#       3 stations.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4310             level=level,
#    4311             inplace=inplace,
# -> 4312             errors=errors,
#    4313         )
#    4314
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4150         for axis, labels in axes.items():
#    4151             if labels is not None:
# -> 4152                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4153
#    4154         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4185                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4186             else:
# -> 4187                 new_axis = axis.drop(labels, errors=errors)
#    4188             result = self.reindex(**{axis_name: new_axis})
#    4189
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['시'] not found in axis"

# %%
# stations['시군구'].unique()
# print(set(stations['시군구']))
stations['시군구'].unique()
# Out:
# array(['계룡', '아산', '예산', '천안 동남', '천안 서북', '청양', '태안', '홍성', '공주', '금산',
#        '논산', '당진', '보령', '부여', '서산', '서천'], dtype=object)

# %%
stations.loc[stations['시군구']=='천안', '시군구'] = '천안 서북'


# stations.loc[stations['시군구'][:2]=='천안' and  stations['시군구'][4]=='동', '시군구'] = '천안 동남'
# stations.loc[stations['시군구'][:2]=='천안', '시군구'] = '천안 서북'
# stations.loc[stations['시군구'][:2]=='천안' and  stations['시군구'][4]!='동' and  stations['시군구'][4]!='서', '시군구'] = '천안 서북'


stations['시군구'].unique()
# Out:
# array(['계룡', '아산', '예산', '천안 동남', '천안 서북', '청양', '태안', '홍성', '공주', '금산',
#        '논산', '당진', '보령', '부여', '서산', '서천'], dtype=object)

# %%
stations[stations['가격']=="-"]
# Out:
#        Oil_store                         주소 가격 셀프      상표    시군구
# 114        영일주유소              충남 아산시 충무로 62  -  N    자가상표     아산
# 115        성원주유소        충남 아산시 영인면 아산호로 772  -  N    자가상표     아산
# 116      문방스타주유소           충남 아산시 아산만로 1504  -  N  현대오일뱅크     아산
# 117        온양주유소     충남 아산시 온천대로 1530 (온천동)  -  N    자가상표     아산
# 62   국민에너지㈜평화주유소     충남 예산군 예산읍 예산산업단지로 8-1  -  Y    자가상표     예산
# 63         선진주유소         충남 예산군 고덕면 상덕로 515  -  N    자가상표     예산
# 64         태영주유소         충남 예산군 신암면 추사로 508  -  N    자가상표     예산
# 65         광시주유소        충남 예산군 광시면 하장대서길 20  -  N    자가상표     예산
# 171        명품주유소   충남 천안시 동남구 광덕면 차령고개로 788  -  N   SK에너지  천안 동남
# 172  성환농협남부지점주유소     충남 천안시 서북구 성환읍 성환중앙로 8  -  N  NH-OIL  천안 서북
# 173       우리들주유소   충남 천안시 동남구 풍세로 990 (청수동)  -  N  현대오일뱅크  천안 동남
# 174        대현주유소     충남 천안시 동남구 목천읍 충절로 704  -  N   GS칼텍스  천안 동남
# 175       신직산주유소      충남 천안시 서북구 직산읍 송기길 90  -  N   GS칼텍스  천안 서북
# 92         명품주유소   충남 천안시 동남구 광덕면 차령고개로 788  -  N   SK에너지  천안 동남
# 93         대현주유소     충남 천안시 동남구 목천읍 충절로 704  -  N   GS칼텍스  천안 동남
# 94        우리들주유소   충남 천안시 동남구 풍세로 990 (청수동)  -  N  현대오일뱅크  천안 동남
# 79        신직산주유소      충남 천안시 서북구 직산읍 송기길 90  -  N   GS칼텍스  천안 서북
# 80   성환농협남부지점주유소     충남 천안시 서북구 성환읍 성환중앙로 8  -  N  NH-OIL  천안 서북
# 28        칠갑산주유소     충청남도 청양군 정산면 칠갑산로 1580  -  N   GS칼텍스     청양
# 29         운곡주유소           충청남도 청양군 청신로 452  -  Y    자가상표     청양
# 30         혜선주유소          충남 청양군 화성면 대청로 64  -  N   SK에너지     청양
# 31         구봉주유소         충남 청양군 화성면 대청로 737  -  N   SK에너지     청양
# 39         소원주유소         충남 태안군 소원면 서해로 678  -  N   SK에너지     태안
# 40        몽산포주유소           충남 태안군 남면 남면로 12  -  N   SK에너지     태안
# 55         홍성에너지        충남 홍성군 홍성읍 충서로 1447  -  Y  현대오일뱅크     홍성
# 56         옥계주유소         충남 홍성군 장곡면 무한로 803  -  N    자가상표     홍성
# 57         갈산주유소         충남 홍성군 갈산면 갈산로 124  -  N  현대오일뱅크     홍성
# 83         가산주유소     충청남도 공주시 의당면 의당전의로 887  -  N  현대오일뱅크     공주
# 84         대한주유소      충남 공주시 소학동길 155 (소학동)  -  N   GS칼텍스     공주
# 85         중장주유소         충남 공주시 계룡면 갑사로 347  -  N    자가상표     공주
# 86       영정대성주유소         충남 공주시 신풍면 영정길 284  -  N  현대오일뱅크     공주
# 40        대둔산주유소        충남 금산군 진산면 태고사로 450  -  N   GS칼텍스     금산
# 41         대양주유소        충남 금산군 부리면 무금로 1831  -  N   SK에너지     금산
# 42         월석주유소       충남 금산군 진산면 휴양림로 2111  -  N   SK에너지     금산
# 79         딸기주유소         충남 논산시 강변로 61(등화동)  -  N  현대오일뱅크     논산
# 80         OK주유소         충남 논산시 연무읍 동안로 961  -  N    자가상표     논산
# 81         덕암주유소        충남 논산시 부적면 계백로 1760  -  N   SK에너지     논산
# 82         가득주유소       충청남도 논산시 시민로 243(내동)  -  N   S-OIL     논산
# 83       우전산업주유소         충남 논산시 연산면 선비로 496  -  N    자가상표     논산
# 84         태성주유소         충남 논산시 벌곡면 수락로 865  -  N   S-OIL     논산
# 98      코멕스GS주유소           충남 당진시 송악읍 복운로 7  -  N   GS칼텍스     당진
# 99         서야주유소         충남 당진시 합덕읍 덕평로 319  -  N  현대오일뱅크     당진
# 100  당진(상)휴게소주유소        충남 당진시 정미면 서해로 4912  -  N   S-OIL     당진
# 54      (주)우리주유소  충청남도 보령시 남포방조제로 791 (신흑동)  -  N   SK에너지     보령
# 55         보령주유소        충남 보령시 웅천읍 충서로 1350  -  N    자가상표     보령
# 56       주교고송영농회       충청남도 보령시 주교면 토정로 886  -  N   SK에너지     보령
# 57         웅천주유소        충남 보령시 웅천읍 충서로 1049  -  N   SK에너지     보령
# 47        123주유소         충남 부여군 석성면 왕릉로 422  -  N   SK에너지     부여
# 48         제일주유소         충남 부여군 부여읍 삼충로 372  -  N    자가상표     부여
# 49         죽림주유소         충남 부여군 내산면 성충로 932  -  N  현대오일뱅크     부여
# 50        구두래주유소         충남 부여군 부여읍 삼충로 184  -  N    자가상표     부여
# 51         대성주유소        충남 부여군 은산면 충절로 3065  -  N   SK에너지     부여
# 86         하나주유소       충남 서산시 안견로 115 (동문동)  -  N   SK에너지     서산
# 87     서산톨게이트주유소         충남 서산시 운산면 운암로 895  -  Y   SK에너지     서산
# 88      하이츠제2주유소        충남 서산시 대산읍 충의로 1869  -  N   GS칼텍스     서산
# 79        신직산주유소      충남 천안시 서북구 직산읍 송기길 90  -  N   GS칼텍스  천안 서북
# 80   성환농협남부지점주유소     충남 천안시 서북구 성환읍 성환중앙로 8  -  N  NH-OIL  천안 서북

# %%
stations = stations[stations['가격'] != '-']
stations.head()
# Out:
#   Oil_store                     주소    가격 셀프     상표 시군구
# 0   대운셀프주유소   충남 계룡시 신도안면 계룡대로 663  1415  Y  SK에너지  계룡
# 1  우체국물류주유소     충남 계룡시 두마면 왕대로 102  1439  Y  알뜰주유소  계룡
# 2     양정주유소    충남 계룡시 엄사면 계백로 3107  1439  Y  S-OIL  계룡
# 3     두마주유소  충청남도 계룡시 엄사면 계백로 3025  1449  N  SK에너지  계룡
# 4  참좋은셀프주유소    충남 계룡시 엄사면 계룡대로 449  1489  Y  S-OIL  계룡

# %%
stations['가격'] = [float(value) for value in stations['가격']]
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
stations.reset_index(inplace=True)
del stations['index']

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1245 entries, 0 to 1244
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Oil_store  1245 non-null   object
#  1   주소         1245 non-null   object
#  2   가격         1245 non-null   float64
#  3   셀프         1245 non-null   object
#  4   상표         1245 non-null   object
#  5   시군구        1245 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 58.5+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

# %%
stations.boxplot(column='가격', by='셀프', figsize=(12,8))

# %%
plt.figure(figsize=(12,8))

sns.boxplot(x="상표", y="가격", hue="셀프", data=stations, palette="Set3")

plt.show()

# %%
plt.figure(figsize=(12,8))

sns.boxplot(x="상표", y="가격", hue="셀프", data=stations, palette="Set3")
sns.swarmplot(x="상표", y="가격", hue="셀프", data=stations, color=".6")

plt.show()

# %%
import json
import folium
import googlemaps
import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
stations.sort_values(by='가격', ascending=False).head()
# Out:
#                    Oil_store                        주소      가격 셀프      상표  \
# 945   CJ대한통운(주)직영 행담도(상행)주유소    충남 당진시 신평면 서해안고속도로 275  1648.0  N  현대오일뱅크
# 944   CJ대한통운(주)직영 행담도(하행)주유소    충남 당진시 신평면 서해안고속도로 275  1648.0  N  현대오일뱅크
# 1244               태양주유소/충전소        충남 천안시 서북구 번영로 613  1598.0  N   GS칼텍스
# 523                태양주유소/충전소        충남 천안시 서북구 번영로 613  1598.0  N   GS칼텍스
# 444                   맘모스주유소  충남 천안시 동남구 만남로 126 (신부동)  1598.0  N   SK에너지
#
#         시군구
# 945      당진
# 944      당진
# 1244  천안 서북
# 523   천안 서북
# 444   천안 동남

# %%
stations.sort_values(by='가격', ascending=True).head()
# Out:
#      Oil_store                    주소      가격 셀프      상표 시군구
# 946     백두산주유소  충남 보령시 대해로 498 (요암동)  1388.0  Y    자가상표  보령
# 947  24시 충청주유소  충남 보령시 대해로 294 (남곡동)  1389.0  Y   알뜰주유소  보령
# 552      태안주유소   충남 태안군 태안읍 안면대로 334  1389.0  Y   알뜰주유소  태안
# 948  24시 대천주유소  충남 보령시 중앙로 172 (대천동)  1389.0  Y   알뜰주유소  보령
# 120    광시농협주유소    충남 예산군 광시면 예당로 187  1390.0  Y  NH-OIL  예산

# %%
import numpy as np



gu_data = pd.pivot_table(stations,
                        index = ['시군구'],
                        values=['가격'],
                        aggfunc=np.mean)

gu_data.head()
# Out:
#               가격
# 시군구
# 계룡   1455.000000
# 공주   1449.349398
# 금산   1463.550000
# 논산   1441.620253
# 당진   1465.295918

# %%
geo_path = '../data/05. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))


map = folium.Map(location=[36.799791, 127.134545],
                zoom_start = 10.5,
                tiles="Stamen Toner")

map.choropleth(geo_data = geo_str,
               data = gu_data,
               columns = [gu_data.index, '가격'],
               fill_color='PuRd',
               key_on='feature.id')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_13037b8d6b6a420c80401e4f78505eee%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_13037b8d6b6a420c80401e4f78505eee%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_13037b8d6b6a420c80401e4f78505eee%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_13037b8d6b6a420c80401e4f78505eee%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
oil_price_top10 = stations.sort_values(by='가격', ascending=False).head(10)
oil_price_top10
# Out:
#                    Oil_store                        주소      가격 셀프      상표  \
# 945   CJ대한통운(주)직영 행담도(상행)주유소    충남 당진시 신평면 서해안고속도로 275  1648.0  N  현대오일뱅크
# 944   CJ대한통운(주)직영 행담도(하행)주유소    충남 당진시 신평면 서해안고속도로 275  1648.0  N  현대오일뱅크
# 1244               태양주유소/충전소        충남 천안시 서북구 번영로 613  1598.0  N   GS칼텍스
# 523                태양주유소/충전소        충남 천안시 서북구 번영로 613  1598.0  N   GS칼텍스
# 444                   맘모스주유소  충남 천안시 동남구 만남로 126 (신부동)  1598.0  N   SK에너지
# 352                태양주유소/충전소        충남 천안시 서북구 번영로 613  1598.0  N   GS칼텍스
# 351                   맘모스주유소  충남 천안시 동남구 만남로 126 (신부동)  1598.0  N   SK에너지
# 1243                   창성주유소   충남 천안시 서북구 성환읍 성환1로 201  1589.0  N   SK에너지
# 522                    창성주유소   충남 천안시 서북구 성환읍 성환1로 201  1589.0  N   SK에너지
# 350                    창성주유소   충남 천안시 서북구 성환읍 성환1로 201  1589.0  N   SK에너지
#
#         시군구
# 945      당진
# 944      당진
# 1244  천안 서북
# 523   천안 서북
# 444   천안 동남
# 352   천안 서북
# 351   천안 동남
# 1243  천안 서북
# 522   천안 서북
# 350   천안 서북

# %%
oil_price_bottom10 = stations.sort_values(by='가격', ascending=True).head(10)
oil_price_bottom10
# Out:
#       Oil_store                     주소      가격 셀프      상표    시군구
# 946      백두산주유소   충남 보령시 대해로 498 (요암동)  1388.0  Y    자가상표     보령
# 947   24시 충청주유소   충남 보령시 대해로 294 (남곡동)  1389.0  Y   알뜰주유소     보령
# 552       태안주유소    충남 태안군 태안읍 안면대로 334  1389.0  Y   알뜰주유소     태안
# 948   24시 대천주유소   충남 보령시 중앙로 172 (대천동)  1389.0  Y   알뜰주유소     보령
# 120     광시농협주유소     충남 예산군 광시면 예당로 187  1390.0  Y  NH-OIL     예산
# 949    (유)대성주유소   충남 보령시 대천로 254 (죽정동)  1390.0  Y   알뜰주유소     보령
# 591   (주)문화셀프랜드     충남 홍성군 홍성읍 내포로 170  1395.0  Y   알뜰주유소     홍성
# 353    (주)좋은주유소    충남 천안시 동남구 광풍로 1687  1395.0  N  현대오일뱅크  천안 동남
# 1166  성거농협클린주유소  충남 천안시 서북구 성거읍 성거길 88  1395.0  Y  현대오일뱅크  천안 서북
# 183   성거농협클린주유소  충남 천안시 서북구 성거읍 성거길 88  1395.0  Y  현대오일뱅크  천안 서북

# %%
gmaps_key = "AIzaSyDZ9x5SpIc2CrEtO8v6D4GuEJADXrPcWQo"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
from tqdm import tqdm_notebook


lat = []
lng = []

for n in tqdm_notebook(oil_price_top10.index):
    try:
        tmp_add = str(oil_price_top10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)
        
        tmp_loc = tmp_map[0].get('geometry')
        lat.append(float(tmp_loc['location']['lat']))
        lng.append(float(tmp_loc['location']['lng']))
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan!")
        
oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
#                    Oil_store                        주소      가격 셀프      상표  \
# 945   CJ대한통운(주)직영 행담도(상행)주유소    충남 당진시 신평면 서해안고속도로 275  1648.0  N  현대오일뱅크
# 944   CJ대한통운(주)직영 행담도(하행)주유소    충남 당진시 신평면 서해안고속도로 275  1648.0  N  현대오일뱅크
# 1244               태양주유소/충전소        충남 천안시 서북구 번영로 613  1598.0  N   GS칼텍스
# 523                태양주유소/충전소        충남 천안시 서북구 번영로 613  1598.0  N   GS칼텍스
# 444                   맘모스주유소  충남 천안시 동남구 만남로 126 (신부동)  1598.0  N   SK에너지
# 352                태양주유소/충전소        충남 천안시 서북구 번영로 613  1598.0  N   GS칼텍스
# 351                   맘모스주유소  충남 천안시 동남구 만남로 126 (신부동)  1598.0  N   SK에너지
# 1243                   창성주유소   충남 천안시 서북구 성환읍 성환1로 201  1589.0  N   SK에너지
# 522                    창성주유소   충남 천안시 서북구 성환읍 성환1로 201  1589.0  N   SK에너지
# 350                    창성주유소   충남 천안시 서북구 성환읍 성환1로 201  1589.0  N   SK에너지
#
#         시군구        lat         lng
# 945      당진  36.944829  126.807532
# 944      당진  36.944829  126.807532
# 1244  천안 서북  36.853156  127.127390
# 523   천안 서북  36.853156  127.127390
# 444   천안 동남  36.823263  127.163846
# 352   천안 서북  36.853156  127.127390
# 351   천안 동남  36.823263  127.163846
# 1243  천안 서북  36.912545  127.127728
# 522   천안 서북  36.912545  127.127728
# 350   천안 서북  36.912545  127.127728

# %%
lat = []
lng = []

for n in tqdm_notebook(oil_price_bottom10.index):
    try:
        tmp_add = str(oil_price_bottom10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)
        
        tmp_loc = tmp_map[0].get('geometry')
        lat.append(float(tmp_loc['location']['lat']))
        lng.append(float(tmp_loc['location']['lng']))
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan!")
        
oil_price_bottom10['lat'] = lat
oil_price_bottom10['lng'] = lng
oil_price_bottom10
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
#       Oil_store                     주소      가격 셀프      상표    시군구        lat  \
# 946      백두산주유소   충남 보령시 대해로 498 (요암동)  1388.0  Y    자가상표     보령  36.323801
# 947   24시 충청주유소   충남 보령시 대해로 294 (남곡동)  1389.0  Y   알뜰주유소     보령  36.335462
# 552       태안주유소    충남 태안군 태안읍 안면대로 334  1389.0  Y   알뜰주유소     태안  36.719912
# 948   24시 대천주유소   충남 보령시 중앙로 172 (대천동)  1389.0  Y   알뜰주유소     보령  36.353681
# 120     광시농협주유소     충남 예산군 광시면 예당로 187  1390.0  Y  NH-OIL     예산  36.551238
# 949    (유)대성주유소   충남 보령시 대천로 254 (죽정동)  1390.0  Y   알뜰주유소     보령  36.365346
# 591   (주)문화셀프랜드     충남 홍성군 홍성읍 내포로 170  1395.0  Y   알뜰주유소     홍성  36.593808
# 353    (주)좋은주유소    충남 천안시 동남구 광풍로 1687  1395.0  N  현대오일뱅크  천안 동남  36.773053
# 1166  성거농협클린주유소  충남 천안시 서북구 성거읍 성거길 88  1395.0  Y  현대오일뱅크  천안 서북  36.873089
# 183   성거농협클린주유소  충남 천안시 서북구 성거읍 성거길 88  1395.0  Y  현대오일뱅크  천안 서북  36.873089
#
#              lng
# 946   126.553834
# 947   126.569603
# 552   126.283980
# 948   126.586005
# 120   126.775315
# 949   126.614754
# 591   126.651470
# 353   127.143015
# 1166  127.201447
# 183   127.201447

# %%
map = folium.Map(location=[36.601659, 126.950659],
                zoom_start = 9)

for n in oil_price_top10.index:
    if pd.notnull(oil_price_top10['lat'][n]):
        folium.CircleMarker([oil_price_top10['lat'][n], oil_price_top10['lng'][n]],
                           radius=15, color='#CD3181',
                           fill_color='#CD3181').add_to(map)
        
        
for n in oil_price_bottom10.index:
    if pd.notnull(oil_price_bottom10['lat'][n]):
        folium.CircleMarker([oil_price_bottom10['lat'][n], oil_price_bottom10['lng'][n]],
                           radius=15, color='#3186cc',
                           fill_color='#3186cc').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_de29651c24894479993c455bdc24af37%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_de29651c24894479993c455bdc24af37%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_de29651c24894479993c455bdc24af37%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_de29651c24894479993c455bdc24af37%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B36.601659%2C%20126.950659%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...
